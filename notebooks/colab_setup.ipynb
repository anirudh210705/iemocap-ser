# %% [markdown]
# # IEMOCAP SER – Colab setup
# Run these cells after selecting a GPU runtime. They prepare the environment but do not start training.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Change this to your repository or upload the project directory.
# !git clone YOUR_REPOSITORY_URL /content/BTP1
# %cd /content/BTP1
# !pip install -e .

# %%
# Point data_root in the config to the copied/extracted IEMOCAP folder.
# !python -m ser.prepare_iemocap --data-root data --output-dir artifacts

# %% [markdown]
# Training is intentionally not started. When ready, use:
# ```bash
# python -m ser.train --config configs/wav2vec2_base.json
# ```
